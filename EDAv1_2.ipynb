# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/consumer
# Out:
# /content/drive/MyDrive/consumer

# %% [markdown]
# # This data is collected from below given link:
# [Dataset link](https://openpsychometrics.org/_rawdata/)
# ##### This data consists mainly of US residents, so the visualization results are also dominated accordingly. And this dataset was updated in the given site on 30 December 2019. This dataset has in total 1350 records and 102 features. The dataset size is 388 KB.

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("data.csv", sep='\t')

# %%
df.head()
# Out:
#    Q1A  Q1I   Q1E  Q2A  Q2I  ...  race  voted  married  familysize             major
# 0    4   18  4225    1    6  ...    11      2        1           2  Computer Science
# 1    4    7  5552    4   13  ...    16      2        3           5               NaN
# 2    3    4  5210    3    6  ...    16      2        1           4               NaN
# 3    4    1  6725    2   17  ...    16      2        1           3         dietetics
# 4    4    4  7551    1   13  ...    16      2        1           2               NaN
#
# [5 rows x 102 columns]

# %%
df.drop(['Q1I','Q2I','Q3I','Q4I','Q5I','Q6I','Q7I','Q8I','Q9I','Q10I','Q11I','Q12I','Q13I','Q14I','Q15I','Q16I','Q17I','Q18I','Q19I'],axis=1,inplace=True)

# %%
df.drop(['Q1E','Q2E','Q3E','Q4E','Q5E','Q6E','Q7E','Q8E','Q9E','Q10E','Q11E','Q12E','Q13E','Q14E','Q15E','Q16E','Q17E','Q18E','Q19E'],axis=1,inplace=True)

# %%
df.drop(['Q1A','Q2A','Q3A','Q4A','Q5A','Q6A','Q7A','Q8A','Q9A','Q10A','Q11A','Q12A','Q13A','Q14A','Q15A','Q16A','Q17A','Q18A','Q19A'],axis=1,inplace=True)

# %%
df.drop(['VCL1','VCL2','VCL3','VCL4','VCL5','VCL6','VCL7','VCL8','VCL9','VCL10','VCL11','VCL12','VCL13','VCL14','VCL15'],axis = 1,inplace = True)

# %%
df.drop(['testelapse','surveyelapse'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   country  introelapse  TIPI1  ...  married  familysize             major
# 0      US            5      2  ...        1           2  Computer Science
# 1      NZ           21      2  ...        3           5               NaN
# 2      GR           14      1  ...        1           4               NaN
# 3      SN          762      7  ...        1           3         dietetics
# 4      US         1118      2  ...        1           2               NaN
#
# [5 rows x 28 columns]

# %%
df.shape
# Out:
# (1350, 28)

# %%
plt.figure(figsize=(25,8))
ax = sns.countplot(x=df['TIPI1'], data=df)
ax.set(xlabel = 'Extraverted, enthusiastic',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
# Out:
# [[<matplotlib.axis.XTick at 0x7f4cf274c750>,
# ...
#  [Text(0, 0, 'NA'),
#   Text(0, 0, 'Disagree strongly'),
#   Text(0, 0, 'Disagree moderately'),
#   Text(0, 0, 'Disagree a little'),
#   Text(0, 0, 'Neither agree nor disagree'),
#   Text(0, 0, 'Agree a little'),
#   Text(0, 0, 'Agree moderately'),
#   Text(0, 0, 'Agree strongly')],
#  Text(0.5, 0, 'Extraverted, enthusiastic')]

# %%
plt.figure(figsize=(25,8))
ax = sns.countplot(x=df['TIPI2'], data=df)
ax.set(xlabel = 'Critical, quarrelsome',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
# Out:
# [[<matplotlib.axis.XTick at 0x7f4cf27b9d90>,
# ...
#  [Text(0, 0, 'NA'),
#   Text(0, 0, 'Disagree strongly'),
#   Text(0, 0, 'Disagree moderately'),
#   Text(0, 0, 'Disagree a little'),
#   Text(0, 0, 'Neither agree nor disagree'),
#   Text(0, 0, 'Agree a little'),
#   Text(0, 0, 'Agree moderately'),
#   Text(0, 0, 'Agree strongly')],
#  Text(0.5, 0, 'Critical, quarrelsome')]

# %%
plt.figure(figsize=(25,8))
ax = sns.countplot(x=df['TIPI3'], data=df)
ax.set(xlabel = 'Dependable, self-disciplined',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
# Out:
# [[<matplotlib.axis.XTick at 0x7f4cf2626310>,
# ...
#  [Text(0, 0, 'NA'),
#   Text(0, 0, 'Disagree strongly'),
#   Text(0, 0, 'Disagree moderately'),
#   Text(0, 0, 'Disagree a little'),
#   Text(0, 0, 'Neither agree nor disagree'),
#   Text(0, 0, 'Agree a little'),
#   Text(0, 0, 'Agree moderately'),
#   Text(0, 0, 'Agree strongly')],
#  Text(0.5, 0, 'Dependable, self-disciplined')]

# %%
plt.figure(figsize=(25,8))
ax = sns.countplot(x=df['TIPI4'], data=df)
ax.set(xlabel = 'Anxious, easily upset',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
# Out:
# [[<matplotlib.axis.XTick at 0x7f4cf2626810>,
# ...
#  [Text(0, 0, 'NA'),
#   Text(0, 0, 'Disagree strongly'),
#   Text(0, 0, 'Disagree moderately'),
#   Text(0, 0, 'Disagree a little'),
#   Text(0, 0, 'Neither agree nor disagree'),
#   Text(0, 0, 'Agree a little'),
#   Text(0, 0, 'Agree moderately'),
#   Text(0, 0, 'Agree strongly')],
#  Text(0.5, 0, 'Anxious, easily upset')]

# %%
plt.figure(figsize=(25,8))
ax = sns.countplot(x=df['TIPI5'], data=df)
ax.set(xlabel = 'Open to new experiences, complex',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
# Out:
# [[<matplotlib.axis.XTick at 0x7f4cf248e510>,
# ...
#  [Text(0, 0, 'NA'),
#   Text(0, 0, 'Disagree strongly'),
#   Text(0, 0, 'Disagree moderately'),
#   Text(0, 0, 'Disagree a little'),
#   Text(0, 0, 'Neither agree nor disagree'),
#   Text(0, 0, 'Agree a little'),
#   Text(0, 0, 'Agree moderately'),
#   Text(0, 0, 'Agree strongly')],
#  Text(0.5, 0, 'Open to new experiences, complex')]

# %%
plt.figure(figsize=(25,8))
ax = sns.countplot(x=df['TIPI6'], data=df)
ax.set(xlabel = 'Reserved, quiet',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
# Out:
# [[<matplotlib.axis.XTick at 0x7f4cf2507c10>,
# ...
#  [Text(0, 0, 'NA'),
#   Text(0, 0, 'Disagree strongly'),
#   Text(0, 0, 'Disagree moderately'),
#   Text(0, 0, 'Disagree a little'),
#   Text(0, 0, 'Neither agree nor disagree'),
#   Text(0, 0, 'Agree a little'),
#   Text(0, 0, 'Agree moderately'),
#   Text(0, 0, 'Agree strongly')],
#  Text(0.5, 0, 'Reserved, quiet')]

# %%
plt.figure(figsize=(25,8))
ax = sns.countplot(x=df['TIPI7'], data=df)
ax.set(xlabel = 'Sympathetic, warm',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
# Out:
# [[<matplotlib.axis.XTick at 0x7f4cf2404050>,
# ...
#  [Text(0, 0, 'NA'),
#   Text(0, 0, 'Disagree strongly'),
#   Text(0, 0, 'Disagree moderately'),
#   Text(0, 0, 'Disagree a little'),
#   Text(0, 0, 'Neither agree nor disagree'),
#   Text(0, 0, 'Agree a little'),
#   Text(0, 0, 'Agree moderately'),
#   Text(0, 0, 'Agree strongly')],
#  Text(0.5, 0, 'Sympathetic, warm')]

# %%
plt.figure(figsize=(25,8))
ax = sns.countplot(x=df['TIPI8'], data=df)
ax.set(xlabel = 'Disorganized, careless',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
# Out:
# [[<matplotlib.axis.XTick at 0x7f4cf2384890>,
# ...
#  [Text(0, 0, 'NA'),
#   Text(0, 0, 'Disagree strongly'),
#   Text(0, 0, 'Disagree moderately'),
#   Text(0, 0, 'Disagree a little'),
#   Text(0, 0, 'Neither agree nor disagree'),
#   Text(0, 0, 'Agree a little'),
#   Text(0, 0, 'Agree moderately'),
#   Text(0, 0, 'Agree strongly')],
#  Text(0.5, 0, 'Disorganized, careless')]

# %%
plt.figure(figsize=(25,8))
ax = sns.countplot(x=df['TIPI9'], data=df)
ax.set(xlabel = 'Calm, emotionally stable',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
# Out:
# [[<matplotlib.axis.XTick at 0x7f4cf2856a10>,
# ...
#  [Text(0, 0, 'NA'),
#   Text(0, 0, 'Disagree strongly'),
#   Text(0, 0, 'Disagree moderately'),
#   Text(0, 0, 'Disagree a little'),
#   Text(0, 0, 'Neither agree nor disagree'),
#   Text(0, 0, 'Agree a little'),
#   Text(0, 0, 'Agree moderately'),
#   Text(0, 0, 'Agree strongly')],
#  Text(0.5, 0, 'Calm, emotionally stable')]

# %%
plt.figure(figsize=(25,8))
ax = sns.countplot(x=df['TIPI10'], data=df)
ax.set(xlabel = 'Conventional, uncreative',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
# Out:
# [[<matplotlib.axis.XTick at 0x7f4cf2633dd0>,
# ...
#  [Text(0, 0, 'NA'),
#   Text(0, 0, 'Disagree strongly'),
#   Text(0, 0, 'Disagree moderately'),
#   Text(0, 0, 'Disagree a little'),
#   Text(0, 0, 'Neither agree nor disagree'),
#   Text(0, 0, 'Agree a little'),
#   Text(0, 0, 'Agree moderately'),
#   Text(0, 0, 'Agree strongly')],
#  Text(0.5, 0, 'Conventional, uncreative')]

# %% [markdown]
# ### Below is the distribution of the time spent by the people on the introduction/landing page (in seconds)

# %%
plt.figure(figsize=(15,8))
sns.distplot(df['introelapse'],kde=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Below is the distribution of education levels of the people involved in the survey.

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(x=df['education'], data=df)
ax.set(xticks = range(5),xticklabels = ['NA','Less than high school', 'High school', 'University degree','Graduate degree'])
# Out:
# [[<matplotlib.axis.XTick at 0x7f4ceebdcc10>,
# ...
#  [Text(0, 0, 'NA'),
#   Text(0, 0, 'Less than high school'),
#   Text(0, 0, 'High school'),
#   Text(0, 0, 'University degree'),
#   Text(0, 0, 'Graduate degree')]]

# %% [markdown]
# ### Below is the distribution of area of the people involved in the survey live in.

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(x=df['urban'], data=df)
ax.set(xticks = range(4),xticklabels = ['NA','Rural (country side)','Suburban','Urban (town, city)'])
# Out:
# [[<matplotlib.axis.XTick at 0x7f4ceebd1450>,
# ...
#  [Text(0, 0, 'NA'),
#   Text(0, 0, 'Rural (country side)'),
#   Text(0, 0, 'Suburban'),
#   Text(0, 0, 'Urban (town, city)')]]

# %% [markdown]
# ### Below is the distribution of gender of the people involved in the survey.

# %%
ax = sns.countplot(x=df['gender'], data=df)
ax.set(xticks = range(4),xticklabels = ['NA','Male','Female','Others'])
# Out:
# [[<matplotlib.axis.XTick at 0x7f4ceeb3a050>,
# ...
#  [Text(0, 0, 'NA'),
#   Text(0, 0, 'Male'),
#   Text(0, 0, 'Female'),
#   Text(0, 0, 'Others')]]

# %%
sns.boxplot(x=df['age'])

# %% [markdown]
# ### Below is the distribution of the religion of the people involved in the survey.

# %%
plt.figure(figsize=(28,8))
ax = sns.countplot(x=df['religion'], data=df)
ax.set(xticks = range(13),xticklabels = ['NA','Agnostic','Athiest','Buddhist','Christian (Catholic)','Christian(Mormon)',' Christian (Protestant) ','Christian (Other)','Hindu','Jewish','Muslim','Sikh','Other'])
# Out:
# [[<matplotlib.axis.XTick at 0x7f4ceea65310>,
# ...
#  [Text(0, 0, 'NA'),
#   Text(0, 0, 'Agnostic'),
#   Text(0, 0, 'Athiest'),
#   Text(0, 0, 'Buddhist'),
#   Text(0, 0, 'Christian (Catholic)'),
#   Text(0, 0, 'Christian(Mormon)'),
#   Text(0, 0, ' Christian (Protestant) '),
#   Text(0, 0, 'Christian (Other)'),
#   Text(0, 0, 'Hindu'),
#   Text(0, 0, 'Jewish'),
#   Text(0, 0, 'Muslim'),
#   Text(0, 0, 'Sikh'),
#   Text(0, 0, 'Other')]]

# %% [markdown]
# ### Below is the distribution of the orientation of the people involved in the survey.

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(x=df['orientation'], data=df)
ax.set(xticks = range(6),xticklabels = ['NA','Heterosexual','Bisexual','Homosexual','Asexual','Other'])
# Out:
# [[<matplotlib.axis.XTick at 0x7f4cee8d3b90>,
# ...
#  [Text(0, 0, 'NA'),
#   Text(0, 0, 'Heterosexual'),
#   Text(0, 0, 'Bisexual'),
#   Text(0, 0, 'Homosexual'),
#   Text(0, 0, 'Asexual'),
#   Text(0, 0, 'Other')]]

# %% [markdown]
# ### Below is the distribution of the race of the people involved in the survey belong to.

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(x=df['race'], data=df)
ax.set(xticks = range(8),xticklabels = ['NA','Asian','Arab','Black','Indigenous Australian','Native American','White','Other'])
# Out:
# [[<matplotlib.axis.XTick at 0x7f4cee9a5a10>,
# ...
#  [Text(0, 0, 'NA'),
#   Text(0, 0, 'Asian'),
#   Text(0, 0, 'Arab'),
#   Text(0, 0, 'Black'),
#   Text(0, 0, 'Indigenous Australian'),
#   Text(0, 0, 'Native American'),
#   Text(0, 0, 'White'),
#   Text(0, 0, 'Other')]]

# %% [markdown]
# ### Below is the distribution of married or unmarried people involved in the survey.

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(x=df['married'], data=df)
ax.set(xticks = range(4),xticklabels = ['NA','Never married','Currently married','Previously married'])
# Out:
# [[<matplotlib.axis.XTick at 0x7f4cee82ccd0>,
# ...
#  [Text(0, 0, 'NA'),
#   Text(0, 0, 'Never married'),
#   Text(0, 0, 'Currently married'),
#   Text(0, 0, 'Previously married')]]

# %% [markdown]
# ### Below is the distribution of country the people involved in the survey live in

# %%
plt.figure(figsize=(30,300))
ax = sns.countplot(y=df['country'], data=df)
for p in ax.patches:
    percentage ='{:,.0f}people'.format(p.get_width())
    width, height =p.get_width(),p.get_height()
    x=p.get_x()+width+0.02
    y=p.get_y()+height/2
    ax.annotate(percentage,(x,y))

# %% [markdown]
# ### Below is the distribution of major subjects and the number of people pursuing them

# %%
plt.figure(figsize=(20,400))
ax = sns.countplot(y="major",data=df)
for p in ax.patches:
    percentage ='{:,.0f}people'.format(p.get_width())
    width, height =p.get_width(),p.get_height()
    x=p.get_x()+width+0.02
    y=p.get_y()+height/2
    ax.annotate(percentage,(x,y))

# %%
ax = sns.catplot(x="TIPI5", hue="urban", kind="count", data=df,height=5,aspect=4,legend=False)
ax.set(xlabel = 'Open to new experiences, complex',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Rural (country side)', 'Suburban','Urban (town, city)']).set_title("Area where they live")

# %% [markdown]
# ### Below are the plots of gender with 10 personality features

# %% [markdown]
# ## From the below plot we can see that most of the peole who disagree strongly that they are extraverted and enthusiastic are males, on the other hand most of the people who agree strongly that they are extraverted and enthusiastic are equal for both males and females.

# %%
ax = sns.catplot(x="TIPI1", hue="gender", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Extraverted, enthusiastic',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Male', 'Female','Other'])

# %% [markdown]
# ## From the below plot we can see that most of the peole who disagree strongly that they are critical and quarrelsome are females, on the other hand most of the people who agree strongly that they are critical and quarrelsome are males.

# %%
ax = sns.catplot(x="TIPI2", hue="gender", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Critical, quarrelsome',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Male', 'Female','Other'])

# %% [markdown]
# ## From the below plot we can see that most of the peole who disagree strongly that they are dependable and self-disciplined are males, on the other hand most of the people who agree strongly that they are dependable and self-disciplined are females.

# %%
ax = sns.catplot(x="TIPI3", hue="gender", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Dependable, self-disciplined',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Male', 'Female','Other'])

# %% [markdown]
# ## From the below plot we can see that most of the peole who disagree strongly that they are anxious and easily upset are males, on the other hand most of the people who agree strongly that they are anxious and easily upset are females.

# %%
ax = sns.catplot(x="TIPI4", hue="gender", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Anxious, easily upset',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Male', 'Female','Other'])

# %% [markdown]
# ## From the below plot we can see that most of the peole who disagree strongly that they are open to new experiences and complex are males, on the other hand most of the people who agree strongly that they are open to new experiences and complex are also males.

# %%
ax = sns.catplot(x="TIPI5", hue="gender", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Open to new experiences, complex',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Male', 'Female','Other'])

# %% [markdown]
# ## From the below plot we can see that most of the peole who disagree strongly that they are reserved and quiet are almost equal for both females and males, on the other hand most of the people who agree strongly that they are reserved and quiet are males.

# %%
ax = sns.catplot(x="TIPI6", hue="gender", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Reserved, quiet',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Male', 'Female','Other'])

# %% [markdown]
# ## From the below plot we can see that most of the peole who disagree strongly that they are sympathetic and warm are males, on the other hand most of the people who agree strongly that they are sympathetic and warm are females.

# %%
ax = sns.catplot(x="TIPI7", hue="gender", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Sympathetic, warm',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Male', 'Female','Other'])

# %% [markdown]
# ## From the below plot we can see that most of the peole who disagree strongly that they are disorganized and careless are females, on the other hand most of the people who agree strongly that they are disorganized and careless are males.

# %%
ax = sns.catplot(x="TIPI8", hue="gender", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Disorganized, careless',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Male', 'Female','Other'])

# %% [markdown]
# ## From the below plot we can see that most of the peole who disagree strongly that they are calm and emotionally stable are females, on the other hand most of the people who agree strongly that they are calm and emotionally stable are males.

# %%
ax = sns.catplot(x="TIPI9", hue="gender", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Calm, emotionally stable',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Male', 'Female','Other'])

# %% [markdown]
# ## From the below plot we can see that most of the peole who disagree strongly that they are conventional and uncreative are males, on the other hand most of the people who agree strongly that they are conventional and uncreative are males.

# %%
ax = sns.catplot(x="TIPI10", hue="gender", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Conventional, uncreative',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Male', 'Female','Other'])

# %% [markdown]
# ### Below are the plots of race with 10 personality features

# %% [markdown]
# ## In the below given plots every personality feature is dominated by White people as this dataset consists majorly of US residents

# %%
ax = sns.catplot(x="TIPI1", hue="race", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Extraverted, enthusiastic',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Asian','Arab','Black','Indigenous Australian','Native American','White','Other'])

# %%
ax = sns.catplot(x="TIPI2", hue="race", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Critical, quarrelsome',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Asian','Arab','Black','Indigenous Australian','Native American','White','Other'])

# %%
ax = sns.catplot(x="TIPI3", hue="race", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Dependable, self-disciplined',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Asian','Arab','Black','Indigenous Australian','Native American','White','Other'])

# %%
ax = sns.catplot(x="TIPI4", hue="race", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Anxious, easily upset',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Asian','Arab','Black','Indigenous Australian','Native American','White','Other'])

# %%
ax = sns.catplot(x="TIPI5", hue="race", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Open to new experiences, complex',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Asian','Arab','Black','Indigenous Australian','Native American','White','Other'])

# %%
ax = sns.catplot(x="TIPI6", hue="race", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Reserved, quiet',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Asian','Arab','Black','Indigenous Australian','Native American','White','Other'])

# %%
ax = sns.catplot(x="TIPI7", hue="race", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Sympathetic, warm',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Asian','Arab','Black','Indigenous Australian','Native American','White','Other'])

# %%
ax = sns.catplot(x="TIPI8", hue="race", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Disorganized, careless',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Asian','Arab','Black','Indigenous Australian','Native American','White','Other'])

# %%
ax = sns.catplot(x="TIPI9", hue="race", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Calm, emotionally stable',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Asian','Arab','Black','Indigenous Australian','Native American','White','Other'])

# %%
ax = sns.catplot(x="TIPI10", hue="race", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Conventional, uncreative',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Asian','Arab','Black','Indigenous Australian','Native American','White','Other'])

# %% [markdown]
# ### Here family size means "Including you, how many children did your mother have?" as given in the meta-data

# %%
df['familysize_interval']=pd.cut(df['familysize'], bins=[1, 2, 3,4,5],precision=2)

# %%
df['familysize_interval'].value_counts()
# Out:
# (1, 2]    568
# (2, 3]    305
# (3, 4]    137
# (4, 5]     60
# Name: familysize_interval, dtype: int64

# %% [markdown]
# ### Below are the plots of family size with 10 personality features

# %% [markdown]
# ## From the below plot it is clear that family sizes between 1-5 disagree moderately that they are extraverted and enthusiastic

# %%
p = sns.catplot(x="familysize_interval", hue="TIPI1", kind="count", data=df,height=5,aspect=4,legend=False)
p.set(xlabel = 'family size',xticks = range(5),xticklabels = ['1','2','3','4','5'])
p.ax.legend(['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly']).set_title("Extraverted, enthusiastic")

# %% [markdown]
# ## From the below plot it is clear that family sizes between 1-5 agree a little that they are critical and quarrelsome

# %%
p = sns.catplot(x="familysize_interval", hue="TIPI2", kind="count", data=df,height=5,aspect=4,legend=False)
p.set(xlabel = 'family size',xticks = range(5),xticklabels = ['1','2','3','4','5'])
p.ax.legend(['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly']).set_title("Critical, quarrelsome")

# %% [markdown]
# ## From the below plot it is clear that family sizes between 1-5 agree moderately that they are dependable and self-disciplined

# %%
p = sns.catplot(x="familysize_interval", hue="TIPI3", kind="count", data=df,height=5,aspect=4,legend=False)
p.set(xlabel = 'family size',xticks = range(5),xticklabels = ['1','2','3','4','5'])
p.ax.legend(['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly']).set_title("Dependable, self-disciplined")

# %% [markdown]
# ## From the below plot it is clear that family sizes between 1-5 agree a little that they are anxious and easily get upset.

# %%
p = sns.catplot(x="familysize_interval", hue="TIPI4", kind="count", data=df,height=5,aspect=4,legend=False)
p.set(xlabel = 'family size',xticks = range(5),xticklabels = ['1','2','3','4','5'])
p.ax.legend(['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly']).set_title("Anxious, easily upset")

# %% [markdown]
# ## From the below plot it is clear that family sizes between 1-5 agree stronglt that they are open to new experiences and complex.

# %%
p = sns.catplot(x="familysize_interval", hue="TIPI5", kind="count", data=df,height=5,aspect=4,legend=False)
p.set(xlabel = 'family size',xticks = range(5),xticklabels = ['1','2','3','4','5'])
p.ax.legend(['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly']).set_title("Open to new experiences, complex")

# %% [markdown]
# ## From the below plot it is clear that family sizes between 1-5 agree a little that they are reserved and quiet

# %%
p = sns.catplot(x="familysize_interval", hue="TIPI6", kind="count", data=df,height=5,aspect=4,legend=False)
p.set(xlabel = 'family size',xticks = range(5),xticklabels = ['1','2','3','4','5'])
p.ax.legend(['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly']).set_title("Reserved, quiet")

# %% [markdown]
# ## From the below plot it is clear that family sizes between 1-5 agree moderately that they are sympathetic and warm.

# %%
p = sns.catplot(x="familysize_interval", hue="TIPI7", kind="count", data=df,height=5,aspect=4,legend=False)
p.set(xlabel = 'family size',xticks = range(5),xticklabels = ['1','2','3','4','5'])
p.ax.legend(['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly']).set_title("Sympathetic, warm")

# %% [markdown]
# ## From the below plot it is clear that family sizes between 1-5 agree a little that they are disorganized and careless.

# %%
p = sns.catplot(x="familysize_interval", hue="TIPI8", kind="count", data=df,height=5,aspect=4,legend=False)
p.set(xlabel = 'family size',xticks = range(5),xticklabels = ['1','2','3','4','5'])
p.ax.legend(['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly']).set_title("Disorganized, careless")

# %% [markdown]
# ## From the below plot it is clear that family sizes between 1-5 agree moderately that they are calm and emotionally stable.

# %%
p = sns.catplot(x="familysize_interval", hue="TIPI9", kind="count", data=df,height=5,aspect=4,legend=False)
p.set(xlabel = 'family size',xticks = range(5),xticklabels = ['1','2','3','4','5'])
p.ax.legend(['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly']).set_title("Calm, emotionally stable")

# %% [markdown]
# ## From the below plot it is clear that family sizes between 1-5 disagree strongly that they are conventional and uncreative.

# %%
p = sns.catplot(x="familysize_interval", hue="TIPI10", kind="count", data=df,height=5,aspect=4,legend=False)
p.set(xlabel = 'family size',xticks = range(5),xticklabels = ['1','2','3','4','5'])
p.ax.legend(loc='upper right',labels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'],title = 'Conventional, Uncreative')

# %% [markdown]
# ### Below are the plots of age with 10 personality features

# %%
df['age_interval']=pd.cut(df['age'], bins=[12, 17, 24, 34, 44,54,64,74],precision=2)

# %% [markdown]
# ## From the below statistic it is clear that most of the people involved in the survey fall in the age-group of 20-30.

# %%
df['age_interval'].value_counts()
# Out:
# (17, 24]    417
# (24, 34]    367
# (12, 17]    192
# (34, 44]    176
# (44, 54]    112
# (54, 64]     63
# (64, 74]     18
# Name: age_interval, dtype: int64

# %% [markdown]
# ## From the below plot it is clear that people in the age group of 18-24 disagree moderately that they are extraverted and enthusiastic, on the other hand people in the age group 65-74 disagree moderately that they are extraverted and enthusiastic

# %%
p = sns.catplot(x="age_interval", hue="TIPI1", kind="count", data=df,height=5,aspect=4,legend=False)
p.set(xlabel = 'Age')
p.ax.legend(loc='upper right',labels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'],title = 'Extraverted, enthusiastic')

# %% [markdown]
# ## From the below plot it is clear that people in the age group of 18-24 agree a little that they are critical and quarrelsome, on the other hand people in the age group 65-74 disagree strongly that they are critical and quarrelsome.

# %%
p = sns.catplot(x="age_interval", hue="TIPI2", kind="count", data=df,height=5,aspect=4,legend=False)
p.set(xlabel = 'Age')
p.ax.legend(loc='upper right',labels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'],title = 'Critical, quarrelsome')

# %% [markdown]
# ## From the below plot it is clear that people in the age group of 18-24 and 25-34 agree  that they are dependable and self-disciplined , on the other hand people in the age group 65-74 agree that they are dependable and self-disciplined.

# %%
p = sns.catplot(x="age_interval", hue="TIPI3", kind="count", data=df,height=5,aspect=4,legend=False)
p.set(xlabel = 'Age')
p.ax.legend(loc='upper right',labels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'],title = 'Dependable, self-disciplined')

# %% [markdown]
# ## From the below plot it is clear that people in the age group of 18-24 agree a little that they are anxious and easily get upset, on the other hand people in the age group 65-74 disagree strongly that they are anxious and easily get upset.

# %%
p = sns.catplot(x="age_interval", hue="TIPI4", kind="count", data=df,height=5,aspect=4,legend=False)
p.set(xlabel = 'Age')
p.ax.legend(loc='upper right',labels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'],title = 'Anxious, easily upset')

# %% [markdown]
# ## From the below plot it is clear that people in the age group of 18-24 or 21-30 agree that they are open to new experiences and complex, on the other hand people in the age group 65-74 agree that they are open to new experiences  and complex.

# %%
p = sns.catplot(x="age_interval", hue="TIPI5", kind="count", data=df,height=5,aspect=4,legend=False)
p.set(xlabel = 'Age')
p.ax.legend(loc='upper right',labels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'],title = 'Open to new experiences, complex')

# %% [markdown]
# ## From the below plot it is clear that people in the age group of 18-24 agree strongly that they are reserved and quiet, on the other hand people in the age group 65-74 agree that they are reserved and quiet.

# %%
p = sns.catplot(x="age_interval", hue="TIPI6", kind="count", data=df,height=5,aspect=4,legend=False)
p.set(xlabel = 'Age')
p.ax.legend(loc='upper right',labels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'],title = 'Reserved, quiet')

# %% [markdown]
# ## From the below plot it is clear that people in the age group of 18-24 agree that they are sympathetic and warm, on the other hand people in the age group 65-74 agree that they are sympathetic and warm.

# %%
p = sns.catplot(x="age_interval", hue="TIPI7", kind="count", data=df,height=5,aspect=4,legend=False)
p.set(xlabel = 'Age')
p.ax.legend(loc='upper right',labels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'],title = 'Sympathetic, warm')

# %% [markdown]
# ## From the below plot it is clear that people in the age group of 18-24 agree a little that they are disorganized and careless, on the other hand people in the age group 65-74 disagree strongly that they are disorganized and careless.

# %%
p = sns.catplot(x="age_interval", hue="TIPI8", kind="count", data=df,height=5,aspect=4,legend=False)
p.set(xlabel = 'Age')
p.ax.legend(loc='upper right',labels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'],title = 'Disorganized, careless')

# %% [markdown]
# ## From the below plot it is clear that people in the age group of 18-24 agree  that they are calm and emotionally stable, on the other hand people in the age group 65-74 agree that they are calm and emotionally stable.

# %%
p = sns.catplot(x="age_interval", hue="TIPI9", kind="count", data=df,height=5,aspect=4,legend=False)
p.set(xlabel = 'Age')
p.ax.legend(loc='upper right',labels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'],title = 'Calm, emotionally stable')

# %% [markdown]
# ## From the below plot it is clear that people in the age group of 18-24 disagree strongly that they are anxious and easily get upset, on the other hand people in the age group 65-74 disagree that they are conventional and uncreative.

# %%
p = sns.catplot(x="age_interval", hue="TIPI10", kind="count", data=df,height=5,aspect=4,legend=False)
p.set(xlabel = 'Age')
p.ax.legend(loc='upper right',labels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'],title = 'Conventional, uncreative')

# %% [markdown]
# ### Below are the plots of education with 10 personality features

# %% [markdown]
# ## From the below plot it is clear that most of the high school and university degree students somewhat agree as well as disagree that they are extraverted and enthusiastic.

# %%
ax = sns.catplot(x="TIPI1", hue="education", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Extraverted, enthusiastic',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Less than high school', 'High school','University degree','Graduate degree'])

# %% [markdown]
# ## From the below plot it is clear that most of the high school and university degree students agree a little that they are critical and quarrelsome.

# %%
ax = sns.catplot(x="TIPI2", hue="education", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Critical, quarrelsome',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Less than high school', 'High school','University degree','Graduate degree'])

# %% [markdown]
# ## From the below plot it is clear that most of the high school and university degree students agree moderately that they are dependable and self-disciplined.

# %%
ax = sns.catplot(x="TIPI3", hue="education", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Dependable, self-disciplined',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Less than high school', 'High school','University degree','Graduate degree'])

# %% [markdown]
# ## From the below plot it is clear that most of the high school and university degree students agree a little that they are anxious and easily get upset.

# %%
ax = sns.catplot(x="TIPI4", hue="education", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Anxious, easily upset',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Less than high school', 'High school','University degree','Graduate degree'])

# %% [markdown]
# ## From the below plot it is clear that most of the high school and university degree students agree strongly that they are open to new experiences and complex.

# %%
ax = sns.catplot(x="TIPI5", hue="education", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Open to new experiences, complex',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Less than high school', 'High school','University degree','Graduate degree'])

# %% [markdown]
# ## From the below plot it is clear that most of the high school agree strongly that they are reserved and quiet.

# %%
ax = sns.catplot(x="TIPI6", hue="education", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Reserved, quiet',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Less than high school', 'High school','University degree','Graduate degree'])

# %% [markdown]
# ## From the below plot it is clear that most of the high school and university degree students agree moderately that they are sympathetic and warm.

# %%
ax = sns.catplot(x="TIPI7", hue="education", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Sympathetic, warm',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Less than high school', 'High school','University degree','Graduate degree'])

# %% [markdown]
# ## From the below plot it is clear that most of the high school and university degree students agree a little  that they are disorganized and careless.

# %%
ax = sns.catplot(x="TIPI8", hue="education", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Disorganized, careless',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Less than high school', 'High school','University degree','Graduate degree'])

# %% [markdown]
# ## From the below plot it is clear that most of the University degree students agree moderately that they are calm and emotionally stable.

# %%
ax = sns.catplot(x="TIPI9", hue="education", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Calm, emotionally stable',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Less than high school', 'High school','University degree','Graduate degree'])

# %% [markdown]
# ## From the below plot it is clear that most of the high school students disagree strongly that they are conventional and uncreative.

# %%
ax = sns.catplot(x="TIPI10", hue="education", kind="count", data=df,height=5,aspect=3,legend=False)
ax.set(xlabel = 'Conventional, uncreative',xticks = range(8),xticklabels = ['NA','Disagree strongly','Disagree moderately','Disagree a little','Neither agree nor disagree','Agree a little','Agree moderately','Agree strongly'])
ax.ax.legend(['NA','Less than high school', 'High school','University degree','Graduate degree'])
